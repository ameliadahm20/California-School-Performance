# %%
import pandas as pd
import datacleaning as dc
import seaborn as sns
school = pd.read_csv('data/California_School_District_Areas_2018-19.csv')
funding = pd.read_excel('data/financialinfo.xlsx')

# %%
school_1 = dc.clean(school) 
school = dc.dataprep(school_1)

# %%
funding['SchoolName'] = funding['District Name'].str.split('(')
funding['SchoolName'] = [x[0].rstrip() for x in funding.SchoolName]
#funding['SchoolName'] = [ str.rstrip()

# %%
merged = school.merge(funding, on = 'SchoolName', how = 'inner')

# %%
merged.tail()
# Out:
#      OBJECTID     Year   FedID   CDCode         CDSCode CountyName  \
# 963       940  2018-19  607260  5872728  58727280000000       Yuba
# 964       941  2018-19  624090  5872736  58727360000000       Yuba
# 965       942  2018-19  631180  5872744  58727440000000       Yuba
# 966       943  2018-19  642330  5872751  58727510000000       Yuba
# 967       944  2018-19  642350  5872769  58727690000000       Yuba
#
#                    SchoolName  SchoolType GradeLow  GradeHigh GradeLowCensus  \
# 963   Camptonville Elementary  Elementary       KG         12             KG
# 964  Marysville Joint Unified     Unified       KG         12             KG
# 965    Plumas Lake Elementary  Elementary       KG          8             KG
# 966                 Wheatland  Elementary       KG          8             KG
# 967      Wheatland Union High        High       07         12             09
#
#      GradeHighCensus               AssistStatus CongressUS SenateCA  \
# 963                8  Differentiated Assistance         03       04
# 964               12  Differentiated Assistance      01,03       04
# 965                8         General Assistance         03       04
# 966                8         General Assistance         03       04
# 967               12         General Assistance         03       04
#
#     AssemblyCA LocaleDistrict UpdateNotes  EnrollTotal  EnrollCharter  \
# 963         03             22         NaN          481            433
# 964      01,03             22         NaN        10153            580
# 965         03             31         NaN         1323              0
# 966         03             31         NaN         1388             98
# 967         03             41         NaN          784              0
#
#      EnrollNonCharter  AfricanAmerican  AfricanAmericanPct  AmericanIndian  \
# 963                48                6                 1.2               8
# 964              9573              356                 3.5             240
# 965              1323               40                 3.0               7
# 966              1290               71                 5.1               9
# 967               784               24                 3.1              12
#
#      AmericanIndianPct  Asian  AsianPct  Filipino  FilipinoPct  Hispanic  \
# 963                1.7      2       0.4         1          0.2        84
# 964                2.4    892       8.8        46          0.5      4401
# 965                0.5     75       5.7        16          1.2       354
# 966                0.6     22       1.6        14          1.0       362
# 967                1.5     27       3.4        14          1.8       221
#
#      HispanicPct  MultipleRace  MultipleRacePct  PacificIslander  \
# 963    17.500000            51             10.6                3
# 964    43.299999           387              3.8               39
# 965    26.799999           145             11.0                5
# 966    26.100000           144             10.4               12
# 967    28.200001            92             11.7                4
#
#      PacificIslanderPct  White   WhitePct  RaceNotReported  \
# 963                 0.6    320  66.500000                6
# 964                 0.4   3701  36.500000               91
# 965                 0.4    679  51.299999                2
# 966                 0.9    754  54.299999                0
# 967                 0.5    383  48.900002                7
#
#      RaceNotReportedPct  EnglishLearner  EnglishLearnerPct  Foster  FosterPct  \
# 963                 1.2               7                1.5       3        0.6
# 964                 0.9            2222               21.9      89        0.9
# 965                 0.2              78                5.9      16        1.2
# 966                 0.0              86                6.2       3        0.2
# 967                 0.9              14                1.8       9        1.1
#
#      Homeless  HomelessPct  Migrant  MigrantPct  Disability  DisabilityPct  \
# 963         1          0.2        0         0.0          71           14.8
# 964       161          1.6       59         0.6        1144           11.3
# 965         3          0.2        0         0.0         121            9.1
# 966        17          1.2        2         0.1         159           11.5
# 967         7          0.9        0         0.0          98           12.5
#
#      SocioEconDisadvantage  SocioEconDisadvantagePct  Unduplicated  \
# 963                    263                 54.700001            39
# 964                   8066                 79.400002          7811
# 965                    492                 37.200001           512
# 966                    658                 47.400002           627
# 967                    349                 44.500000           350
#
#      UnduplicatedPct  ELATested  ELAStdMetPct  MathTested  MathStdMetPct  \
# 963        81.199997       32.0     68.800003        32.0      68.800003
# 964        81.599998     5236.0     36.900002      5235.0      26.799999
# 965        38.700001      814.0     58.599998       814.0      52.000000
# 966        48.599998      845.0     51.500000       845.0      40.500000
# 967        44.599998      212.0     50.500000       212.0      23.600000
#
#      CCPrepCohortCount  CCPrepPct  AbsentEligCount  AbsentPct  \
# 963                NaN        NaN            533.0        5.4
# 964              555.0  23.600000          10516.0       10.6
# 965                NaN        NaN           1385.0        5.1
# 966                NaN        NaN           1487.0        5.8
# 967              173.0  35.299999            833.0       13.2
#
#      GradCohortCount    GradPct  UCCSUReqMetPct  DropOutPct  EnrollCumulative  \
# 963             44.0  95.500000       16.700001         4.5             552.0
# 964            627.0  86.599998       29.500000        10.0           10830.0
# 965              NaN        NaN             NaN         NaN            1482.0
# 966              NaN        NaN             NaN         NaN            1509.0
# 967            173.0  85.000000       37.400002        15.0             873.0
#
#      SuspPct   SHAPE_Length    SHAPE_Area  smallenrollment  mediumenrollment  \
# 963      1.4   79862.488656  2.462935e+08                0                 1
# 964      6.1  349629.046956  2.028548e+09                0                 0
# 965      5.3   87661.104071  1.626634e+08                0                 1
# 966      2.9  143419.536122  5.138135e+08                0                 1
# 967      7.3  158205.506594  6.764769e+08                0                 1
#
#      largeenrollment  xlenrollment  charterpct  noncharterpct  unified  elem  \
# 963                0             0   90.020790       9.979210        0     1
# 964                0             1    5.712597      94.287403        1     0
# 965                0             0    0.000000     100.000000        0     1
# 966                0             0    7.060519      92.939481        0     1
# 967                0             0    0.000000     100.000000        0     0
#
#      high  suburban  rural  town  city  assistance  target  \
# 963     0         0      0     0     0           1       1
# 964     0         0      0     0     0           1       0
# 965     0         0      0     0     0           0       0
# 966     0         0      0     0     0           0       0
# 967     1         0      1     0     0           0       0
#
#                        District Name County Name (District)  \
# 963   Camptonville Elementary (Yuba)                   Yuba
# 964  Marysville Joint Unified (Yuba)                   Yuba
# 965    Plumas Lake Elementary (Yuba)                   Yuba
# 966                 Wheatland (Yuba)                   Yuba
# 967      Wheatland Union High (Yuba)                   Yuba
#
#        District Type (District)  \
# 963  Elementary School District
# 964     Unified School District
# 965  Elementary School District
# 966  Elementary School District
# 967        High School District
#
#      Current Exp of Educ per ADA (Ed Code 41372) (District)
# 963                                            17375.0
# 964                                            11837.0
# 965                                            10016.0
# 966                                            12875.0
# 967                                            12435.0

# %%
merged['ELAPercent'] = school_1['ELAStdMetPct']

# %%
sns.scatterplot(y = 'ELAPercent', x = 'Current Exp of Educ per ADA (Ed Code 41372) (District)', data = merged)
